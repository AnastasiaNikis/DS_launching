# %%
from data_loader import Load_data

# %%
happy = Load_data('World Happiness Report 2024.csv')

# %%
happy
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2358     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2359     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2360     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2361     Zimbabwe  2022     3.296220            7.670073        0.666172
# 2362     Zimbabwe  2023     3.572386            7.678590        0.693817
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2363 non-null   object
#  1   year                              2363 non-null   int64
#  2   Life Ladder                       2363 non-null   float64
#  3   Log GDP per capita                2335 non-null   float64
#  4   Social support                    2350 non-null   float64
#  5   Healthy life expectancy at birth  2300 non-null   float64
#  6   Freedom to make life choices      2327 non-null   float64
#  7   Generosity                        2282 non-null   float64
#  8   Perceptions of corruption         2238 non-null   float64
#  9   Positive affect                   2339 non-null   float64
#  10  Negative affect                   2347 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
from visualisation import Visualizer

# %%
viz = Visualizer(happy)
viz.Barplot(happy[happy['Country name'] == 'Afghanistan'], 'year', 'Healthy life expectancy at birth')

# %%
viz = Visualizer(happy)
viz.Line(happy[happy['Country name'] == 'Afghanistan'], 'year', 'Healthy life expectancy at birth')

# %%
viz = Visualizer(happy)
viz.Scatterplot_3d(happy, 'Social support', 'Healthy life expectancy at birth', 'Perceptions of corruption')

# %%
viz = Visualizer(happy)
viz.Scatterplot(happy, 'Healthy life expectancy at birth', 'Perceptions of corruption')

# %%
from data_processing import Data_processing

# %%
proc = Data_processing

# %%
proc.EmptyData(happy)
# Out:
# в столбце Country name - 0 пустых значений
# в столбце year - 0 пустых значений
# в столбце Life Ladder - 0 пустых значений
# в столбце Log GDP per capita - 28 пустых значений
# в столбце Social support - 13 пустых значений
# в столбце Healthy life expectancy at birth - 63 пустых значений
# в столбце Freedom to make life choices - 36 пустых значений
# в столбце Generosity - 81 пустых значений
# в столбце Perceptions of corruption - 125 пустых значений
# в столбце Positive affect - 24 пустых значений
# в столбце Negative affect - 16 пустых значений

# %%
happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2363 non-null   object
#  1   year                              2363 non-null   int64
#  2   Life Ladder                       2363 non-null   float64
#  3   Log GDP per capita                2335 non-null   float64
#  4   Social support                    2350 non-null   float64
#  5   Healthy life expectancy at birth  2300 non-null   float64
#  6   Freedom to make life choices      2327 non-null   float64
#  7   Generosity                        2282 non-null   float64
#  8   Perceptions of corruption         2238 non-null   float64
#  9   Positive affect                   2339 non-null   float64
#  10  Negative affect                   2347 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
happy.describe(include = 'all')
# Out:
#        Country name         year  Life Ladder  Log GDP per capita  \
# count          2363  2363.000000  2363.000000         2335.000000
# unique          165          NaN          NaN                 NaN
# top         Lebanon          NaN          NaN                 NaN
# freq             18          NaN          NaN                 NaN
# mean            NaN  2014.763860     5.483562            9.399673
# std             NaN     5.059436     1.125523            1.152062
# min             NaN  2005.000000     1.281271            5.526723
# 25%             NaN  2011.000000     4.646750            8.506165
# 50%             NaN  2015.000000     5.448725            9.502946
# 75%             NaN  2019.000000     6.323592           10.392974
# max             NaN  2023.000000     8.018934           11.675588
#
#         Social support  Healthy life expectancy at birth  \
# count      2350.000000                       2300.000000
# ...

# %%
happy.head(30)
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0   Afghanistan  2008     3.723590            7.350416        0.450662
# 1   Afghanistan  2009     4.401778            7.508646        0.552308
# 2   Afghanistan  2010     4.758381            7.613900        0.539075
# 3   Afghanistan  2011     3.831719            7.581259        0.521104
# 4   Afghanistan  2012     3.782938            7.660506        0.520637
# 5   Afghanistan  2013     3.572100            7.680333        0.483552
# 6   Afghanistan  2014     3.130896            7.670638        0.525568
# 7   Afghanistan  2015     3.982855            7.653833        0.528597
# 8   Afghanistan  2016     4.220169            7.650370        0.559072
# 9   Afghanistan  2017     2.661718            7.647830        0.490880
# 10  Afghanistan  2018     2.694303            7.630801        0.507516
# 11  Afghanistan  2019     2.375092            7.640086        0.419973
# ...

# %%
proc.FulFill(happy)
# Out:
# Заменены пустые значения:
# в столбце Country name - мода Argentina - категориальное значение
# в столбце year - медиана 2015.0
# в столбце Life Ladder - медиана 5.448724746704102
# в столбце Log GDP per capita - медиана 9.50294589996338
# в столбце Social support - медиана 0.8343945443630219
# в столбце Healthy life expectancy at birth - медиана 65.0999984741211
# в столбце Freedom to make life choices - медиана 0.7711215615272522
# в столбце Generosity - медиана -0.02161329798400395
# в столбце Perceptions of corruption - медиана 0.7984966337680817
# в столбце Positive affect - медиана 0.6634199619293213
# в столбце Negative affect - медиана 0.2621752023696899

# %%
happy.head(30)
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0   Afghanistan  2008     3.723590            7.350416        0.450662
# 1   Afghanistan  2009     4.401778            7.508646        0.552308
# 2   Afghanistan  2010     4.758381            7.613900        0.539075
# 3   Afghanistan  2011     3.831719            7.581259        0.521104
# 4   Afghanistan  2012     3.782938            7.660506        0.520637
# 5   Afghanistan  2013     3.572100            7.680333        0.483552
# 6   Afghanistan  2014     3.130896            7.670638        0.525568
# 7   Afghanistan  2015     3.982855            7.653833        0.528597
# 8   Afghanistan  2016     4.220169            7.650370        0.559072
# 9   Afghanistan  2017     2.661718            7.647830        0.490880
# 10  Afghanistan  2018     2.694303            7.630801        0.507516
# 11  Afghanistan  2019     2.375092            7.640086        0.419973
# ...

# %%
happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2363 non-null   object
#  1   year                              2363 non-null   int64
#  2   Life Ladder                       2363 non-null   float64
#  3   Log GDP per capita                2363 non-null   float64
#  4   Social support                    2363 non-null   float64
#  5   Healthy life expectancy at birth  2363 non-null   float64
#  6   Freedom to make life choices      2363 non-null   float64
#  7   Generosity                        2363 non-null   float64
#  8   Perceptions of corruption         2363 non-null   float64
#  9   Positive affect                   2363 non-null   float64
#  10  Negative affect                   2363 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
proc.EmptyData(happy)
# Out:
# в столбце Country name - 0 пустых значений
# в столбце year - 0 пустых значений
# в столбце Life Ladder - 0 пустых значений
# в столбце Log GDP per capita - 0 пустых значений
# в столбце Social support - 0 пустых значений
# в столбце Healthy life expectancy at birth - 0 пустых значений
# в столбце Freedom to make life choices - 0 пустых значений
# в столбце Generosity - 0 пустых значений
# в столбце Perceptions of corruption - 0 пустых значений
# в столбце Positive affect - 0 пустых значений
# в столбце Negative affect - 0 пустых значений
